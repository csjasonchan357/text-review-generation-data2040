# %%
# %cd /content/drive/My Drive/text-review-generation-data2040/src/ctrl
# Out:
# /content/drive/My Drive/text-review-generation-data2040/src/ctrl

# %%
# !git checkout lower_memory
# Out:
# Already on 'lower_memory'
# Your branch is up to date with 'origin/lower_memory'.

# %%
#%tensorflow_version 1.x
#!pip uninstall -y tensorflow
# !pip2 install -q tensorflow-gpu==1.14
# Out:
#      |████████████████████████████████| 377.0MB 28kB/s
#      |████████████████████████████████| 3.2MB 53.9MB/s
#      |████████████████████████████████| 491kB 59.7MB/s
# ERROR: tensorflow 2.1.0 has requirement tensorboard<2.2.0,>=2.1.0, but you'll have tensorboard 1.14.0 which is incompatible.
# ERROR: tensorflow 2.1.0 has requirement tensorflow-estimator<2.2.0,>=2.1.0rc0, but you'll have tensorflow-estimator 1.14.0 which is incompatible.

# %%
# !patch -b /usr/local/lib/python2.7/dist-packages/tensorflow_estimator/python/estimator/keras.py estimator.patch
# Out:
# patching file /usr/local/lib/python2.7/dist-packages/tensorflow_estimator/python/estimator/keras.py

# %%
# !pip2 install -q fastBPE
# !pip2 install -q gsutil
# Out:
#   Building wheel for fastBPE (setup.py) ... done
#      |████████████████████████████████| 2.3MB 9.4MB/s
#      |████████████████████████████████| 143kB 60.5MB/s
#      |████████████████████████████████| 61kB 9.2MB/s
#      |████████████████████████████████| 2.7MB 52.1MB/s
#   Building wheel for gsutil (setup.py) ... done
#   Building wheel for gcs-oauth2-boto-plugin (setup.py) ... done
#   Building wheel for retry-decorator (setup.py) ... done
#   Building wheel for SocksiPy-branch (setup.py) ... done
#   Building wheel for pyu2f (setup.py) ... done

# %%
# !gsutil -m cp -r gs://sf-ctrl/seqlen256_v1.ckpt .
# Out:
# Copying gs://sf-ctrl/seqlen256_v1.ckpt/checkpoint...
# Copying gs://sf-ctrl/seqlen256_v1.ckpt/model.ckpt-413000.data-00000-of-00001...
# Copying gs://sf-ctrl/seqlen256_v1.ckpt/model.ckpt-413000.index...
# Copying gs://sf-ctrl/seqlen256_v1.ckpt/model.ckpt-413000.meta...
# | [4/4 files][ 12.7 GiB/ 12.7 GiB] 100% Done  13.9 MiB/s ETA 00:00:00
# Operation completed over 4 objects/12.7 GiB.

# %%
# !python2 generation.py --model seqlen256_v1.ckpt/model.ckpt-413000.data-00000-of-00001 --print_once
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0515 02:27:56.035398 140133920204672 deprecation_wrapper.py:119] From generation.py:6: The name tf.enable_eager_execution is deprecated. Please use tf.compat.v1.enable_eager_execution instead.
#
# W0515 02:27:57.049983 140133920204672 deprecation_wrapper.py:119] From generation.py:43: The name tf.random.set_random_seed is deprecated. Please use tf.compat.v1.random.set_random_seed instead.
#
# 246534 unique words
# 2020-05-15 02:27:57.320806: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcuda.so.1
# 2020-05-15 02:27:57.360681: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-15 02:27:57.361250: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1640] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-05-15 02:27:57.373839: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2020-05-15 02:27:57.577612: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# 2020-05-15 02:27:57.665327: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcufft.so.10.0
# 2020-05-15 02:27:57.687463: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcurand.so.10.0
# 2020-05-15 02:27:57.923827: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusolver.so.10.0
# 2020-05-15 02:27:58.066170: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusparse.so.10.0
# 2020-05-15 02:27:58.569062: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# 2020-05-15 02:27:58.569265: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-15 02:27:58.570191: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-15 02:27:58.570745: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1763] Adding visible gpu devices: 0
# 2020-05-15 02:27:58.571124: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2020-05-15 02:27:58.681804: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-15 02:27:58.682636: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5616bcb2af40 executing computations on platform CUDA. Devices:
# 2020-05-15 02:27:58.682671: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-05-15 02:27:58.685532: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2000175000 Hz
# 2020-05-15 02:27:58.685944: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5616bcb2bb80 executing computations on platform Host. Devices:
# 2020-05-15 02:27:58.685981: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): <undefined>, <undefined>
# 2020-05-15 02:27:58.686136: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-15 02:27:58.686639: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1640] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-05-15 02:27:58.686695: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2020-05-15 02:27:58.686715: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# 2020-05-15 02:27:58.686735: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcufft.so.10.0
# 2020-05-15 02:27:58.686753: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcurand.so.10.0
# 2020-05-15 02:27:58.686771: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusolver.so.10.0
# 2020-05-15 02:27:58.686790: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusparse.so.10.0
# 2020-05-15 02:27:58.686809: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# 2020-05-15 02:27:58.686871: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-15 02:27:58.687429: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-15 02:27:58.687920: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1763] Adding visible gpu devices: 0
# 2020-05-15 02:27:58.687981: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2020-05-15 02:27:58.689096: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1181] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-05-15 02:27:58.689123: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1187]      0
# 2020-05-15 02:27:58.689134: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1200] 0:   N
# 2020-05-15 02:27:58.689292: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-15 02:27:58.689832: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-15 02:27:58.690344: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:40] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-05-15 02:27:58.690382: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1326] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# W0515 02:28:14.217360 140133920204672 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# W0515 02:28:14.217603 140133920204672 deprecation_wrapper.py:119] From generation.py:132: The name tf.train.AdagradOptimizer is deprecated. Please use tf.compat.v1.train.AdagradOptimizer instead.
#
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256)]        0
# __________________________________________________________________________________________________
# tied_embedding_softmax (TiedEmb multiple             315810054   input_1[0][0]
#                                                                  encoder[0][0]
# __________________________________________________________________________________________________
# encoder (Encoder)               (None, 256, 1280)    1322154496  tied_embedding_softmax[0][0]
# ==================================================================================================
# Total params: 1,637,964,550
# Trainable params: 1,637,964,550
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Loading vocabulary from vocab ...
# Read 6086453827 words (246531 unique) from vocabulary file.
# Loading codes from codes ...
# Read 200000 codes from the codes file.
# 2020-05-15 02:28:15.798604: W tensorflow/core/framework/allocator.cc:107] Allocation of 1262254080 exceeds 10% of system memory.
# tcmalloc: large alloc 1262256128 bytes == 0x56170be76000 @  0x7f737843db6b 0x7f737845d379 0x7f73352f1754 0x7f73352acc8a 0x7f7334fe9f11 0x7f7334ffcf08 0x7f7338a74a8b 0x7f733892eea8 0x5616baba1bba 0x5616baba6926 0x5616bab9f2aa 0x5616bab9ed19 0x5616babcf94f 0x5616babcabe2 0x5616babca60d 0x5616bab79356 0x7f7378058b97 0x5616bab78c4a
# WARNING! THIS VERSION OF THE CODE ALLOWS FOR LOWER MEMORY USAGE THROUGH FP16 QUANTIZATION BUT IS UNTESTED; GENERATIONS MAY BE WORSE. USE AT YOUR OWN RISK.
# ENTER PROMPT: Reviews Rating 5.0
# 2020-05-15 02:35:48.108387: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# ---------------------------------------
# Reviews Rating 5.0 out of 5 stars
#  Rating: 4.0
#  I bought this for my husband and he loves it. It is a great product at an excellent price. The only thing that would make it better was if the cord were longer.
#  Rating: 4.0
#  This item works as advertised. My wife uses it to listen to music on her phone while she works. She has had no problems with it, so far.
#  Rating: 4.0
#  Works well but not sure how long will last
#  Rating: 4.0
#  Good quality sound from such small speakers. Easy to use and set up.
#  Rating: 4.0
#  Great little speaker system. Very easy to use.
#  Rating: 4.0
#  These speakers are very good quality. They have nice bass response without being overpowering. However, they do get pretty loud when you turn them up all the way.
#  Rating: 4.0
#  For what these are, they're great. They're small, portable, inexpensive, and work well. I've used them in various situations (office, kitchen, bathroom, etc) and they've worked just fine.
#  Rating: 4.0
#  I like the size and ease of use, however there isn't much volume or bass. But it's perfect for travel
#  Rating: 4.0
#  I love these. I can take them anywhere and put them wherever I want. And they don't cost much.
#  Rating: 4.0
#  I got two sets of these, one
#
# WARNING! THIS VERSION OF THE CODE ALLOWS FOR LOWER MEMORY USAGE THROUGH FP16 QUANTIZATION BUT IS UNTESTED; GENERATIONS MAY BE WORSE. USE AT YOUR OWN RISK.
# ENTER PROMPT: Reviews Rating 1.0
# ---------------------------------------
# Reviews Rating 1.0 out of 5 starsThe book was provided by the publisher for review purposes.Rating: 2.0
#  I have read all three books in this series and found them to be very enjoyable. This one is not as good though. It seems like it has been written over a long weekend. There are many grammatical errors that make me wonder if English isn't her first language.
#  Rating: 2.0
#  I really enjoyed reading about the characters from previous books. However, there were too many typos throughout the book.
#  Rating: 2.0
#  I am so disappointed with this book! I loved the other two books, but this one just didn't do anything for me. I felt no connection between the main characters. They had nothing going on except sex. And they weren't even together long.
#  Rating: 2.0
#  I love these stories but this one seemed rushed and incomplete. Not enough time spent developing their relationship or getting into it.
#  Rating: 2.0
#  I liked the story line but the writing style made it hard to read. Too much detail and way too wordy.
#  Rating: 2.0
#  I thought this would be an interesting read, since I'm interested in the history of the Civil War. But after only a few pages, I realized how poorly researched this was. For example, the author states that Lincoln did not want to go to war because he wanted peace at
#
# WARNING! THIS VERSION OF THE CODE ALLOWS FOR LOWER MEMORY USAGE THROUGH FP16 QUANTIZATION BUT IS UNTESTED; GENERATIONS MAY BE WORSE. USE AT YOUR OWN RISK.
# ENTER PROMPT: Traceback (most recent call last):
#   File "generation.py", line 172, in <module>
#     prompt = raw_input('ENTER PROMPT: ') if not use_py3 else input('ENTER PROMPT: ')
