# %%
# %cd /content/drive/My Drive/text-review-generation-data2040/src/ctrl
# Out:
# [Errno 2] No such file or directory: '/content/drive/My Drive/text-review-generation-data2040/src/ctrl'
# /content

# %% [markdown]
# # New Section

# %%
# !ls
# Out:
# CODE_OF_CONDUCT.md		      ModelCard.pdf
# codes				      __pycache__
# control_codes.py		      pytorch_generation.py
# control_codes.txt		      pytorch_transformer.py
# convert_tf_to_huggingface_pytorch.py  README.md
# ctrl.gif			      seqlen256_v1.ckpt
# ctrl-merges.txt			      source_attribution.py
# ctrl-vocab.json			      training_utils
# estimator.patch			      transformer.py
# generation.py			      transformer.pyc
# LICENSE.txt			      vocab

# %%
# !pip install -q fastBPE
# !pip install -q gsutil
# %tensorflow_version 2.x
# !pip uninstall -y tensorflow
# !pip install -q tensorflow-gpu==1.14.0
# Out:
# ...
#      |████████████████████████████████| 2.3MB 9.6MB/s
#      |████████████████████████████████| 174kB 55.1MB/s
#      |████████████████████████████████| 61kB 8.2MB/s
#      |████████████████████████████████| 61kB 8.6MB/s
#      |████████████████████████████████| 112kB 53.9MB/s
#      |████████████████████████████████| 2.7MB 53.3MB/s
# ...
# Uninstalling tensorflow-2.2.0rc4:
#   Successfully uninstalled tensorflow-2.2.0rc4
#      |████████████████████████████████| 377.0MB 45kB/s
#      |████████████████████████████████| 3.2MB 36.2MB/s
#      |████████████████████████████████| 491kB 56.7MB/s

# %%
# !gsutil -m cp -r gs://sf-ctrl/seqlen256_v1.ckpt/ .
# Out:
# Copying gs://sf-ctrl/seqlen256_v1.ckpt/checkpoint...
# Copying gs://sf-ctrl/seqlen256_v1.ckpt/model.ckpt-413000.index...
# Copying gs://sf-ctrl/seqlen256_v1.ckpt/model.ckpt-413000.data-00000-of-00001...
# Copying gs://sf-ctrl/seqlen256_v1.ckpt/model.ckpt-413000.meta...
# \ [4/4 files][ 12.7 GiB/ 12.7 GiB] 100% Done  55.3 MiB/s ETA 00:00:00
# Operation completed over 4 objects/12.7 GiB.

# %%
# !patch -b /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/keras.py estimator.patch
# Out:
# patching file /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/keras.py

# %%
# %cd training_utils/
# Out:
# /content/drive/My Drive/text-review-generation-data2040/src/ctrl/training_utils

# %%
# !python make_tf_records.py --text_file Movies_and_TV_5.txt --control_code Movies --sequence_len 256
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# !python3 training.py --model_dir ../seqlen256_v1.ckpt/ --iterations 2 --use
# Out:
# Streaming output truncated to the last 5000 lines.
# 2020-05-08 16:46:13.622167: I tensorflow/core/common_runtime/placer.cc:54] encoder/encoder_layer_20/layer_normalization_41/beta/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp)/job:localhost/replica:0/task:0/device:GPU:0
# encoder/encoder_layer_20/layer_normalization_41/beta/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2020-05-08 16:46:13.622182: I tensorflow/core/common_runtime/placer.cc:54] encoder/encoder_layer_20/layer_normalization_41/beta/Assign: (AssignVariableOp)/job:localhost/replica:0/task:0/device:GPU:0
# encoder/encoder_layer_20/layer_normalization_41/beta/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2020-05-08 16:46:13.622198: I tensorflow/core/common_runtime/placer.cc:54] encoder/encoder_layer_20/layer_normalization_41/beta/Read/ReadVariableOp: (ReadVariableOp)/job:localhost/replica:0/task:0/device:GPU:0
# ...

# %%
# !ls
# Out:
# make_tf_records.py  seqlen256_v1.ckpt	  toys_and_games_5.txt.tfrecords
# README.md	    Toys_and_Games_5.txt  training.py
